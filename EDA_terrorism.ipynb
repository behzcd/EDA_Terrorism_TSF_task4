# %% [markdown]
# ##Author - Bekhzodbek Mukhammadaliev

# %% [markdown]
# ####Objectives:
#
# - Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism'
# - As a security/defense analyst, try to find out the hot zone of terrorism.
# - What all security issues and insights you can derive by EDA?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#calling the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/globalterrorismdb_0718dist.csv", encoding='ISO-8859-1', low_memory=False)
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# ##Data Structure and Content

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %% [markdown]
# ##Data Cleaning

# %%
#percentage of missing values
((df.isnull().sum().sum())/df.size)*100
# Out:
# 56.481718962414206

# %% [markdown]
# So, more than half of the data is missing. We can not just drop the NaN values because we loose the big part of our data.

# %% [markdown]
# Since there are many and uknown columns, we select the important columns to our analysis

# %%
df = df[['iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 'provstate', 'city', 'attacktype1_txt', 'targtype1_txt', 'weaptype1_txt', 'nkill', 'nwound', 'gname']]
df
# Out:
#         iyear  imonth  iday         country_txt                   region_txt  \
# 0        1970       7     2  Dominican Republic  Central America & Caribbean
# 1        1970       0     0              Mexico                North America
# 2        1970       1     0         Philippines               Southeast Asia
# 3        1970       1     0              Greece               Western Europe
# 4        1970       1     0               Japan                    East Asia
# ...       ...     ...   ...                 ...                          ...
# 181686   2017      12    31             Somalia           Sub-Saharan Africa
# 181687   2017      12    31               Syria   Middle East & North Africa
# 181688   2017      12    31         Philippines               Southeast Asia
# 181689   2017      12    31               India                   South Asia
# 181690   2017      12    31         Philippines               Southeast Asia
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   iyear            181691 non-null  int64
#  1   imonth           181691 non-null  int64
#  2   iday             181691 non-null  int64
#  3   country_txt      181691 non-null  object
#  4   region_txt       181691 non-null  object
#  5   provstate        181270 non-null  object
#  6   city             181257 non-null  object
#  7   attacktype1_txt  181691 non-null  object
#  8   targtype1_txt    181691 non-null  object
#  9   weaptype1_txt    181691 non-null  object
#  10  nkill            171378 non-null  float64
#  11  nwound           165380 non-null  float64
#  12  gname            181691 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 18.0+ MB

# %% [markdown]
# If you look at the columns, they are a bit difficult to use. So, we convert the column names to the ones we can easily understand and use.

# %%
cols = {'iyear': 'Year', 'imonth': 'Month', 'iday': 'Day', 'country_txt': 'Country', 'region_txt': 'Region', 'provstate': 'State', 'city': 'City', 'attacktype1_txt': 'Attack_Type', 'targtype1_txt': 'Target', 'weaptype1_txt': 'Weapon_Type', 'nkill': 'Killed', 'nwound': 'Wounded', 'gname': 'Group_Name'}
df.rename(columns=cols, inplace=True)
df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_Type                       Target  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   Region       181691 non-null  object
#  5   State        181270 non-null  object
#  6   City         181257 non-null  object
#  7   Attack_Type  181691 non-null  object
#  8   Target       181691 non-null  object
#  9   Weapon_Type  181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Group_Name   181691 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 18.0+ MB

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# Region             0
# State            421
# City             434
# Attack_Type        0
# Target             0
# Weapon_Type        0
# Killed         10313
# Wounded        16311
# Group_Name         0
# dtype: int64

# %% [markdown]
# We gonna apply mode and mean of the columns to fill the NaN values

# %%
# Fill NaN values with the mean of the column (for numeric data)
df['Wounded'] = df['Wounded'].fillna(df['Wounded'].mean()).astype(int)
df['Killed'] = df['Killed'].fillna(df['Killed'].mean()).astype(int)

# Fill NaN values with the mode of the column (for categorical data)
df['State'] = df['State'].fillna(df['State'].mode()[0])
df['City'] = df['City'].fillna(df['City'].mode()[0])
df['Target'] = df['Target'].fillna(df['Target'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# Region         0
# State          0
# City           0
# Attack_Type    0
# Target         0
# Weapon_Type    0
# Killed         0
# Wounded        0
# Group_Name     0
# dtype: int64

# %% [markdown]
# ##EDA Analysis

# %% [markdown]
# ###Univariate Analysis

# %%
plt.figure(figsize=(12, 6))
attack_type_counts = df['Attack_Type'].value_counts().head(10)
sns.barplot(x=attack_type_counts.values, y=attack_type_counts.index, palette='muted')
plt.title('Top 10 Most Attacked Types')
plt.xlabel('Number of Attacks')
plt.ylabel('Attack Type')
plt.show()

# %% [markdown]
# Analayzed:
# - the most Attack happened with Bombing/Explosion
# - the next most Attacks happened with Armed Assault and Assassination

# %%
plt.figure(figsize=(12, 6))
target_country_counts = df[df['Target'].notna()]['Country'].value_counts().head(10)
sns.barplot(x=target_country_counts.values, y=target_country_counts.index, palette='summer')
plt.title('Top 10 Most Attacked Targets by Country')
plt.xlabel('Number of Attacks')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# As you can see that the most attacked country by Terrorism, and the next ones are Pakistan and Afghanistan.

# %%
(df['Target'].value_counts().head(10)/df['Target'].shape[0])*100
# Out:
# Private Citizens & Property       23.947801
# Military                          15.401974
# Police                            13.487735
# Government (General)              11.713844
# Business                          11.375907
# Transportation                     3.742068
# Utilities                          3.314969
# Unknown                            3.246171
# Religious Figures/Institutions     2.443709
# Educational Institution            2.378764
# Name: Target, dtype: float64

# %%
plt.figure(figsize=(12, 6))
target_counts = df['Target'].value_counts().head(10)
sns.barplot(x=target_counts.index, y=target_counts.values, palette='rocket')
plt.title('Top 10 Most Attacked Targets')
plt.xlabel('Number of Attacks')
plt.xticks(rotation=90)
plt.ylabel('Target')
plt.show()

# %% [markdown]
# Analyzed:
# - The most Attacked Target is 'Private Citizens & Property' which is approximately 25%
# - The next Targets which is 'Military','Police', 'Government', 'Business' with 10-20%

# %%
plt.figure(figsize=(12, 6))
region_counts = df['Region'].value_counts().head(10)
sns.barplot(x=region_counts.values, y=region_counts.index, palette='colorblind')
plt.title('Top 10 Most Attacked Regions')
plt.xlabel('Number of Attacks')
plt.ylabel('Region')
plt.show()

# %%
plt.figure(figsize=(12, 6))
state_counts = df['State'].value_counts().head(10)
sns.barplot(y=state_counts.values, x=state_counts.index, palette='cubehelix')
plt.title('Top 10 Most Attacked States')
plt.xlabel('Number of Attacks')
plt.ylabel('State')
plt.show()

# %% [markdown]
# Analyzed:
# - The most attacked region is Middle East and North Africa, then South Asia
# - The Most attacked State is Baghdad.

# %%
(df['Weapon_Type'].value_counts().head()/df['Weapon_Type'].shape[0])*100
# Out:
# Explosives    50.869883
# Firearms      32.210731
# Unknown        8.342185
# Incendiary     6.128537
# Melee          2.011657
# Name: Weapon_Type, dtype: float64

# %%
plt.figure(figsize=(12, 6))
weapon_counts = df['Weapon_Type'].value_counts().head(10)
sns.barplot(x=weapon_counts.values, y=weapon_counts.index, palette='coolwarm')
plt.title('Top 10 Most Used Weapons')
plt.xlabel('Number of Attacks')
plt.ylabel('Weapon Type')
plt.show()

# %% [markdown]
# So, Nearly 51% of the weapons used is Explosives, and the next one is Firearms showed more than 32%.

# %%
# Number of attacks each year
x_year = df['Year'].unique()
y_count_years = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (12,7))
sns.barplot(x = x_year,
           y = y_count_years,
           palette = 'ch:start=.2,rot=-.3')
plt.xticks(rotation = 90)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks each year')
plt.title('Attack_of_Years')
plt.show()

# %%
plt.figure(figsize=(12, 6))
deaths_by_year = df.groupby('Year')['Killed'].sum()
sns.lineplot(x=deaths_by_year.index, y=deaths_by_year.values, color='red',
    markers=True, dashes=True)
plt.title('Number of Deaths by Year')
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.show()

# %% [markdown]
# Analayzed:
# - The year 2014 marked a significant surge in terrorist attacks, with a notable increase in the number of incidents reported onwards from that year. During the period from 2014 to 2018, the impact of terrorism resulted in a substantial loss of lives, with an average of over 50,000 people being killed annually. The peak in casualties was observed in 2014, where the death toll exceeded 45,000.

# %%
# Terrorist Activities by Region in Each Year
plt.figure(figsize = (12,7))
sns.kdeplot(x = df['Year'], hue = df['Region'])
plt.title('Terrorist Activities by Region in each Year',fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Frequency of Attacks',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ###Bivariate Analysis

# %%
plt.figure(figsize=(12, 6))
wounded_killed_by_region = df.groupby('Region')[['Wounded', 'Killed']].sum().sort_values(by='Killed', ascending=False)
sns.barplot(data=wounded_killed_by_region, x='Killed', y=wounded_killed_by_region.index, palette='flare')
sns.barplot(data=wounded_killed_by_region, x='Wounded', y=wounded_killed_by_region.index, palette='coolwarm')
plt.title('Wounded and Killed People by Region')
plt.xlabel('Number of People')
plt.ylabel('Region')
plt.legend(['Killed', 'Wounded'])
plt.show()

# %% [markdown]
# Analyzed:
# - The region of Middle East & North Africa has experienced the highest number of casualties due to terrorism, with more than 140,000 people killed and over 200,000 people wounded. The region has faced significant challenges and devastating consequences as a result of terrorist activities.

# %%
# Top 10 Terrorist Organizations with Highest Terror Attacks
plt.figure(figsize=(10,10))
sns.barplot(y = df['Group_Name'].value_counts()[1:11].values, x = df['Group_Name'].value_counts()[1:11].index,palette='rocket')
plt.title('Top 10 Terrorist Organization with Highest Terror Attacks',fontsize=15)
plt.xlabel('Number of Attacks',fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Terrorist Groups',fontsize=15)
plt.show()

# %%
number_one_group = df['Group_Name'].value_counts().index[1]
group_df = df[df['Group_Name'] == 'Taliban']

# Perform analysis and visualization specific to the number one group: Taliban

# Visualize the most common attack types by Taliban
plt.figure(figsize=(12, 6))
group_attack_types = group_df['Attack_Type'].value_counts().head(10)
sns.barplot(x=group_attack_types.values, y=group_attack_types.index, palette='Set1')
plt.title(f"Most Common Attack Types by {number_one_group}")
plt.xlabel('Number of Attacks')
plt.ylabel('Attack Type')
plt.show()

# %%
# Visualize the targeted countries by the number one group
plt.figure(figsize=(12, 6))
group_target_countries = group_df['Country'].value_counts().head(10)
sns.barplot(x=group_target_countries.values, y=group_target_countries.index, palette='rocket')
plt.title(f"Top 10 Targeted Countries by {number_one_group}")
plt.xlabel('Number of Attacks')
plt.ylabel('Country')
plt.show()

# %%
# Visualize the most used weapons by the number one group
plt.figure(figsize=(12, 6))
group_weapon_counts = group_df['Weapon_Type'].value_counts().head(10)
sns.barplot(x=group_weapon_counts.values, y=group_weapon_counts.index, palette='Paired')
plt.title(f"Most Used Weapons by {number_one_group}")
plt.xlabel('Number of Attacks')
plt.ylabel('Weapon Type')
plt.show()

# %% [markdown]
# ###Summary:
#
# Based on the Exploratory Data Analysis, the following insights can be derived from the dataset:
#
# 1. Private Citizens and Property are the most targeted entities, followed by military, police, and government.
# 2. The Middle East & North Africa region has experienced the highest number of casualties, with over 140,000 people killed and more than 200,000 people wounded.
# 3. Iraq is the country most affected by terrorist attacks, with a significant number of casualties.
# 4. Baghdad is the most affected state and city, indicating the need for increased security measures in that area.
# 5. The year 2014 witnessed the highest number of terror attacks, with an average of 45 attacks per day.
# 6. The most common attack type is Bombing/Explosion.
# 7. Explosives are consistently the most popular weapon of choice for terrorists.
# 8. The Taliban is responsible for the majority of terror attacks, particularly since 2012.
#
# Recommendations:
#
# 1. Enhance security and surveillance measures, particularly in densely populated areas where private citizens and property are targeted frequently.
# 2. Strengthen surveillance and security efforts in the Middle East & North African regions due to their high vulnerability to terrorist activities.
# 3. Implement strict border control policies to prevent the movement of explosives and weapons across regions.
# 4. Collaborate and support law enforcement agencies, intelligence services, and relevant authorities by providing information and tips regarding potential threats and suspicious activities.
#
# By implementing these recommendations, it is possible to improve overall security and mitigate the impact of terrorism on affected regions.
